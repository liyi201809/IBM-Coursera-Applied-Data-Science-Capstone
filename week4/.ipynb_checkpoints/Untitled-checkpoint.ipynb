# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
address = 'Amsterdam'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Amsterdam are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Amsterdam are 52.3727598, 4.8936041.

# %%
map_newyork = folium.Map(location=[latitude, longitude], zoom_start=12)
map_newyork
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
CLIENT_ID = 'GITTZBK0YLFZKHX4UVFZSEEJFK4NVAP2USZ3VF4RGW11OX3G' # your Foursquare ID
CLIENT_SECRET = '3APPLT12DN0R5BTICA4MF4HI0EMC0LN3FOAE5N2AMKXPG4JB' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)

neighborhood_latitude = latitude     # neighborhood latitude value
neighborhood_longitude = longitude   # neighborhood longitude value

neighborhood_name = 'Amsterdam' # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# Your credentails:
# CLIENT_ID: GITTZBK0YLFZKHX4UVFZSEEJFK4NVAP2USZ3VF4RGW11OX3G
# CLIENT_SECRET:3APPLT12DN0R5BTICA4MF4HI0EMC0LN3FOAE5N2AMKXPG4JB
# Latitude and longitude values of Amsterdam are 52.3727598, 4.8936041.

# %%
# type your answer here

LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 500 # define radius

url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)
url # display URL

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5eb12b649da7ee001b908504'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'De Wallen',
#   'headerFullLocation': 'De Wallen, Amsterdam',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 77,
#   'suggestedBounds': {'ne': {'lat': 52.3772598045, 'lng': 4.900961089819226},
#    'sw': {'lat': 52.368259795499995, 'lng': 4.886247110180774}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '514c4a7ae4b00b0ee3659e4c',
#        'name': 'Hotel V',
#        'location': {'address': 'Nes 49',
#         'lat': 52.37112510807593,
#         'lng': 4.893665414854814,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37112510807593,
#           'lng': 4.893665414854814}],
#         'distance': 182,
#         'postalCode': '1017 XV',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Nes 49', '1017 XV Amsterdam', 'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '65684573'}},
#       'referralId': 'e-0-514c4a7ae4b00b0ee3659e4c-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '514e0cbce4b0679548f4d62a',
#        'name': 'The Lobby',
#        'location': {'address': 'Nes 49',
#         'lat': 52.37115889725467,
#         'lng': 4.893661205025948,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37115889725467,
#           'lng': 4.893661205025948}],
#         'distance': 178,
#         'postalCode': '1012 KD',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Nes 49', '1012 KD Amsterdam', 'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-514e0cbce4b0679548f4d62a-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '552bf0d0498e4b2863f0a6a3',
#        'name': 'Scheltema',
#        'location': {'address': 'Rokin 9',
#         'lat': 52.37220458591638,
#         'lng': 4.893175115256038,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37220458591638,
#           'lng': 4.893175115256038}],
#         'distance': 68,
#         'postalCode': '1012 KK',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Rokin 9', '1012 KK Amsterdam', 'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d114951735',
#          'name': 'Bookstore',
#          'pluralName': 'Bookstores',
#          'shortName': 'Bookstore',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-552bf0d0498e4b2863f0a6a3-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b9ff646f964a520f44d37e3',
#        'name': 'Dam',
#        'location': {'address': 'Dam',
#         'lat': 52.372824,
#         'lng': 4.893702,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.372824,
#           'lng': 4.893702}],
#         'distance': 9,
#         'postalCode': '1012 NP',
#         'cc': 'NL',
#         'neighborhood': 'Stadsdeel Centrum',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Dam', '1012 NP Amsterdam', 'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b9ff646f964a520f44d37e3-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a270317f964a52075841fe3',
#        'name': 'Wynand Fockink',
#        'location': {'address': 'Pijlsteeg 31',
#         'crossStreet': 'Dam',
#         'lat': 52.37230074036698,
#         'lng': 4.895253277609685,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37230074036698,
#           'lng': 4.895253277609685}],
#         'distance': 123,
#         'postalCode': '1012 HH',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Pijlsteeg 31 (Dam)',
#          '1012 HH Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d186941735',
#          'name': 'Liquor Store',
#          'pluralName': 'Liquor Stores',
#          'shortName': 'Liquor Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_liquor_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a270317f964a52075841fe3-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a270329f964a5209b841fe3',
#        'name': 'Proeflokaal De Drie Fleschjes',
#        'location': {'address': 'Gravenstraat 18',
#         'lat': 52.374202693253054,
#         'lng': 4.89223921638973,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.374202693253054,
#           'lng': 4.89223921638973}],
#         'distance': 185,
#         'postalCode': '1012 NM',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Gravenstraat 18',
#          '1012 NM Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a270329f964a5209b841fe3-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a270666f964a520d88a1fe3',
#        'name': 'Sofitel Legend The Grand Amsterdam',
#        'location': {'address': 'Oudezijds Voorburgwal 197',
#         'lat': 52.371092886381604,
#         'lng': 4.8954104782092145,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.371092886381604,
#           'lng': 4.8954104782092145}],
#         'distance': 222,
#         'postalCode': '1012 EX',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Oudezijds Voorburgwal 197',
#          '1012 EX Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '408686723'}},
#       'referralId': 'e-0-4a270666f964a520d88a1fe3-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51b874d9498e4e1545e1bb48',
#        'name': 'Rob Wigboldus Vishandel',
#        'location': {'address': 'Zoutsteeg 6',
#         'lat': 52.374143731473275,
#         'lng': 4.893967344454074,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.374143731473275,
#           'lng': 4.893967344454074}],
#         'distance': 156,
#         'postalCode': '1012 LX',
#         'cc': 'NL',
#         'country': 'Nederland',
#         'formattedAddress': ['Zoutsteeg 6', '1012 LX', 'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1c7941735',
#          'name': 'Snack Place',
#          'pluralName': 'Snack Places',
#          'shortName': 'Snacks',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51b874d9498e4e1545e1bb48-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ae46620f964a520549a21e3',
#        'name': 'Metropolitan',
#        'location': {'address': 'Warmoesstraat 135',
#         'lat': 52.37387632881563,
#         'lng': 4.8960625489447755,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37387632881563,
#           'lng': 4.8960625489447755}],
#         'distance': 208,
#         'postalCode': '1012 JB',
#         'cc': 'NL',
#         'neighborhood': 'De Wallen',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Warmoesstraat 135',
#          '1012 JB Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1d0941735',
#          'name': 'Dessert Shop',
#          'pluralName': 'Dessert Shops',
#          'shortName': 'Desserts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ae46620f964a520549a21e3-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a26ff86f964a520f87f1fe3',
#        'name': 'Café Belgique',
#        'location': {'address': 'Gravenstraat 2',
#         'lat': 52.374271075403435,
#         'lng': 4.893235736130103,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.374271075403435,
#           'lng': 4.893235736130103}],
#         'distance': 170,
#         'postalCode': '1012 NM',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Gravenstraat 2',
#          '1012 NM Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a26ff86f964a520f87f1fe3-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a270771f964a520cf8d1fe3',
#        'name': 'FuLu Mandarijn Amsterdam',
#        'location': {'address': 'Rokin 26',
#         'lat': 52.37168384206423,
#         'lng': 4.8927204733305265,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37168384206423,
#           'lng': 4.8927204733305265}],
#         'distance': 133,
#         'postalCode': '1012 KS',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Rokin 26', '1012 KS Amsterdam', 'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a270771f964a520cf8d1fe3-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a7ead92f964a5200df21fe3',
#        'name': 'De Bierkoning',
#        'location': {'address': 'Paleisstraat 125',
#         'lat': 52.372404361652826,
#         'lng': 4.889795393950229,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.372404361652826,
#           'lng': 4.889795393950229}],
#         'distance': 261,
#         'postalCode': '1012',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Paleisstraat 125',
#          '1012 Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '5370f356bcbc57f1066c94c2',
#          'name': 'Beer Store',
#          'pluralName': 'Beer Stores',
#          'shortName': 'Beer Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/beergarden_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a7ead92f964a5200df21fe3-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '524465b711d2e7db1161f280',
#        'name': 'W Amsterdam',
#        'location': {'address': 'Spuistraat 175',
#         'lat': 52.37278705389788,
#         'lng': 4.890005886500148,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37278705389788,
#           'lng': 4.890005886500148}],
#         'distance': 244,
#         'postalCode': '1012 VN',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Spuistraat 175',
#          '1012 VN Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-524465b711d2e7db1161f280-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55e5ff02498e9eb3a234f62c',
#        'name': 'Kaagman & Kortekaas',
#        'location': {'address': 'St. Nicolaasstraat 43',
#         'lat': 52.37487809219845,
#         'lng': 4.892455494640974,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37487809219845,
#           'lng': 4.892455494640974}],
#         'distance': 248,
#         'postalCode': '1012NJ',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['St. Nicolaasstraat 43',
#          '1012NJ Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'shortName': 'French',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55e5ff02498e9eb3a234f62c-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a27db76f964a520f4931fe3',
#        'name': 'De Bijenkorf',
#        'location': {'address': 'Dam 1 3F',
#         'lat': 52.37375309999999,
#         'lng': 4.895270600000001,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37375309999999,
#           'lng': 4.895270600000001}],
#         'distance': 158,
#         'postalCode': '1012 JS',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Dam 1 3F', '1012 JS Amsterdam', 'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1f6941735',
#          'name': 'Department Store',
#          'pluralName': 'Department Stores',
#          'shortName': 'Department Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/departmentstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a27db76f964a520f4931fe3-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '514dd657e4b0579579288eef',
#        'name': 'Old Amsterdam Cheese Store',
#        'location': {'address': 'Damrak 62',
#         'lat': 52.37486200638898,
#         'lng': 4.895301176842613,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37486200638898,
#           'lng': 4.895301176842613}],
#         'distance': 260,
#         'postalCode': '1012 LM',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Damrak 62', '1012 LM Amsterdam', 'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d11e951735',
#          'name': 'Cheese Shop',
#          'pluralName': 'Cheese Shops',
#          'shortName': 'Cheese Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_cheese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-514dd657e4b0579579288eef-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a54aedef964a52032b31fe3',
#        'name': 'W139',
#        'location': {'address': 'Warmoesstraat 139',
#         'lat': 52.37377702016631,
#         'lng': 4.89590164664914,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37377702016631,
#           'lng': 4.89590164664914}],
#         'distance': 192,
#         'postalCode': '1012 JB',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Warmoesstraat 139',
#          '1012 JB Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1e2931735',
#          'name': 'Art Gallery',
#          'pluralName': 'Art Galleries',
#          'shortName': 'Art Gallery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a54aedef964a52032b31fe3-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56070374498e2ffed0e3b817',
#        'name': 'MR PORTER',
#        'location': {'address': 'Spuistraat 175',
#         'lat': 52.372760911986425,
#         'lng': 4.8902208998770025,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.372760911986425,
#           'lng': 4.8902208998770025}],
#         'distance': 229,
#         'postalCode': '1012 VN',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Spuistraat 175',
#          '1012 VN Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1cc941735',
#          'name': 'Steakhouse',
#          'pluralName': 'Steakhouses',
#          'shortName': 'Steakhouse',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56070374498e2ffed0e3b817-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4db13d245da32cf2df57903d',
#        'name': 'Greenhouse',
#        'location': {'address': 'Oudezijds Voorburgwal 191',
#         'lat': 52.371597,
#         'lng': 4.895958,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.371597,
#           'lng': 4.895958}],
#         'distance': 205,
#         'postalCode': '1012 EW',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Oudezijds Voorburgwal 191',
#          '1012 EW Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '52c71aaf3cf9994f4e043d17',
#          'name': 'Marijuana Dispensary',
#          'pluralName': 'Marijuana Dispensaries',
#          'shortName': 'Dispensary',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/dispensary_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4db13d245da32cf2df57903d-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ab13fe4f964a520b86820e3',
#        'name': 'BeerTemple',
#        'location': {'address': 'Nieuwezijds Voorburgwal 250',
#         'lat': 52.371999118512846,
#         'lng': 4.890545158673645,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.371999118512846,
#           'lng': 4.890545158673645}],
#         'distance': 224,
#         'postalCode': '1012 RR',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Nieuwezijds Voorburgwal 250',
#          '1012 RR Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '56aa371ce4b08b9a8d57356c',
#          'name': 'Beer Bar',
#          'pluralName': 'Beer Bars',
#          'shortName': 'Beer Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '454987116'}},
#       'referralId': 'e-0-4ab13fe4f964a520b86820e3-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5c1e45e07b385f002c8e7759',
#        'name': 'Hummingbird',
#        'location': {'address': '217 Spuistraat',
#         'lat': 52.371641,
#         'lng': 4.88955,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.371641,
#           'lng': 4.88955}],
#         'distance': 302,
#         'postalCode': '1012 VN',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['217 Spuistraat',
#          '1012 VN Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5c1e45e07b385f002c8e7759-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a270706f964a520bc8c1fe3',
#        'name': 'Koninklijk Paleis Amsterdam',
#        'location': {'address': 'Nieuwezijds Voorburgwal 147',
#         'crossStreet': 'Dam',
#         'lat': 52.37315932108544,
#         'lng': 4.891614317893982,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37315932108544,
#           'lng': 4.891614317893982}],
#         'distance': 142,
#         'postalCode': '1012 RJ',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Nieuwezijds Voorburgwal 147 (Dam)',
#          '1012 RJ Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a14',
#          'name': 'Palace',
#          'pluralName': 'Palaces',
#          'shortName': 'Palace',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a270706f964a520bc8c1fe3-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a2707d2f964a520ec8e1fe3',
#        'name': 'Oriental City',
#        'location': {'address': 'Oudezijds Voorburgwal 177-179',
#         'crossStreet': 'Damstraat',
#         'lat': 52.371911733724474,
#         'lng': 4.895993555789719,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.371911733724474,
#           'lng': 4.895993555789719}],
#         'distance': 187,
#         'postalCode': '1012 EV',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Oudezijds Voorburgwal 177-179 (Damstraat)',
#          '1012 EV Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a2707d2f964a520ec8e1fe3-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53e8efc1498ea17469974c4b',
#        'name': 'Wok to Walk',
#        'location': {'address': 'Damstraat 44',
#         'lat': 52.371773,
#         'lng': 4.896363,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.371773,
#           'lng': 4.896363}],
#         'distance': 217,
#         'postalCode': '1012 JM',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Damstraat 44',
#          '1012 JM Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'shortName': 'Asian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53e8efc1498ea17469974c4b-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b3f7c743b4e00002c6a81d6',
#        'name': 'Soho House Amsterdam',
#        'location': {'address': 'Spuistraat 210',
#         'lat': 52.37206542660903,
#         'lng': 4.889217007892203,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37206542660903,
#           'lng': 4.889217007892203}],
#         'distance': 308,
#         'postalCode': '1012 VT',
#         'cc': 'NL',
#         'neighborhood': 'Stadsdeel Centrum',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Spuistraat 210',
#          '1012 VT Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '554346310'}},
#       'referralId': 'e-0-5b3f7c743b4e00002c6a81d6-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51d98583498e78da6626be60',
#        'name': 'De Koffieschenkerij',
#        'location': {'address': 'Oudekerksplein 27',
#         'crossStreet': 'Oudezijds Voorburgwal',
#         'lat': 52.37404292238903,
#         'lng': 4.898427170724094,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37404292238903,
#           'lng': 4.898427170724094}],
#         'distance': 357,
#         'postalCode': '1012 GX',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Oudekerksplein 27 (Oudezijds Voorburgwal)',
#          '1012 GX Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51d98583498e78da6626be60-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b07effcf964a520580123e3',
#        'name': 'P.G.C. Hajenius',
#        'location': {'address': 'Rokin 92-96',
#         'lat': 52.369664794474964,
#         'lng': 4.891970997902468,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.369664794474964,
#           'lng': 4.891970997902468}],
#         'distance': 361,
#         'postalCode': '1012 KZ',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Rokin 92-96', '1012 KZ Amsterdam', 'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d123951735',
#          'name': 'Smoke Shop',
#          'pluralName': 'Smoke Shops',
#          'shortName': 'Smoke Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/tobacco_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b07effcf964a520580123e3-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d011a414f56b60cac72a537',
#        'name': 'Red Light Radio',
#        'location': {'address': 'Oudekerksplein 22',
#         'crossStreet': 'Warmoesstraat',
#         'lat': 52.37462597115612,
#         'lng': 4.8978403747170765,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37462597115612,
#           'lng': 4.8978403747170765}],
#         'distance': 355,
#         'postalCode': '1012 GZ',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Oudekerksplein 22 (Warmoesstraat)',
#          '1012 GZ Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1e5931735',
#          'name': 'Music Venue',
#          'pluralName': 'Music Venues',
#          'shortName': 'Music Venue',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d011a414f56b60cac72a537-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b918a0460d11b002c3228e1',
#        'name': 'Cecconi’s',
#        'location': {'address': 'Spuistraat 210',
#         'lat': 52.372066,
#         'lng': 4.888894,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.372066,
#           'lng': 4.888894}],
#         'distance': 329,
#         'postalCode': '1012 VT',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Spuistraat 210',
#          '1012 VT Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '547393782'}},
#       'referralId': 'e-0-5b918a0460d11b002c3228e1-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '521cd22b498e281e2810f09d',
#        'name': 'TonTon Club',
#        'location': {'address': 'Sint Annendwarsstraat 6',
#         'crossStreet': 'Oudekerksplein',
#         'lat': 52.37396242797088,
#         'lng': 4.897226693629578,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37396242797088,
#           'lng': 4.897226693629578}],
#         'distance': 280,
#         'postalCode': '1012 HC',
#         'cc': 'NL',
#         'neighborhood': 'De Wallen',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Sint Annendwarsstraat 6 (Oudekerksplein)',
#          '1012 HC Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1e1931735',
#          'name': 'Arcade',
#          'pluralName': 'Arcades',
#          'shortName': 'Arcade',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/arcade_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '85476835'}},
#       'referralId': 'e-0-521cd22b498e281e2810f09d-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '589e54ab2c55ec7cf2e2f707',
#        'name': "Rosalia's Menagerie",
#        'location': {'address': 'Kloveniersburgwal 20',
#         'crossStreet': 'Koestraat',
#         'lat': 52.3716780431221,
#         'lng': 4.899174389497594,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.3716780431221,
#           'lng': 4.899174389497594}],
#         'distance': 397,
#         'postalCode': '1012 CV',
#         'cc': 'NL',
#         'neighborhood': 'De Wallen',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Kloveniersburgwal 20 (Koestraat)',
#          '1012 CV Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d11e941735',
#          'name': 'Cocktail Bar',
#          'pluralName': 'Cocktail Bars',
#          'shortName': 'Cocktail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '444960401'}},
#       'referralId': 'e-0-589e54ab2c55ec7cf2e2f707-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d4c3e9be1ec6dcb4af9d675',
#        'name': 'Spuistraat',
#        'location': {'address': 'Spuistraat',
#         'lat': 52.37422861053173,
#         'lng': 4.890621297272977,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37422861053173,
#           'lng': 4.890621297272977}],
#         'distance': 260,
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Spuistraat', 'Amsterdam', 'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1f9931735',
#          'name': 'Road',
#          'pluralName': 'Roads',
#          'shortName': 'Road',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/highway_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d4c3e9be1ec6dcb4af9d675-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a26ffccf964a52011811fe3',
#        'name': 'Bierproeflokaal In de Wildeman',
#        'location': {'address': 'Kolksteeg 3',
#         'lat': 52.376221607108576,
#         'lng': 4.89513383418524,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.376221607108576,
#           'lng': 4.89513383418524}],
#         'distance': 399,
#         'postalCode': '1012 PT',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Kolksteeg 3', '1012 PT Amsterdam', 'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a26ffccf964a52011811fe3-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a2705c4f964a520c9881fe3',
#        'name': 'Greenwoods',
#        'location': {'address': 'Singel 103',
#         'lat': 52.375832,
#         'lng': 4.891188,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.375832,
#           'lng': 4.891188}],
#         'distance': 379,
#         'postalCode': '1012 VG',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Singel 103', '1012 VG Amsterdam', 'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a2705c4f964a520c9881fe3-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ee4db136c25be9630ca266e',
#        'name': 'De Laatste Kruimel',
#        'location': {'address': 'Langebrugsteeg 4',
#         'lat': 52.36921970740506,
#         'lng': 4.892809970063676,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.36921970740506,
#           'lng': 4.892809970063676}],
#         'distance': 397,
#         'postalCode': '1012 GB',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Langebrugsteeg 4',
#          '1012 GB Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ee4db136c25be9630ca266e-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bf7fe9d5ec320a130dc87d3',
#        'name': 'Puccini Bomboni',
#        'location': {'address': 'Singel 184',
#         'crossStreet': 'Oude Leliestraat',
#         'lat': 52.37459191628638,
#         'lng': 4.889032031045729,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37459191628638,
#           'lng': 4.889032031045729}],
#         'distance': 371,
#         'postalCode': '1016 AA',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Singel 184 (Oude Leliestraat)',
#          '1016 AA Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b31',
#          'name': 'Chocolate Shop',
#          'pluralName': 'Chocolate Shops',
#          'shortName': 'Chocolate Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/candystore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bf7fe9d5ec320a130dc87d3-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5ad253cdb9ac381d6e190d7e',
#        'name': 'Tony’s Chocolonely Super Store',
#        'location': {'address': 'Oudebrugsteeg 15',
#         'lat': 52.375589333001614,
#         'lng': 4.8968016252617526,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.375589333001614,
#           'lng': 4.8968016252617526}],
#         'distance': 382,
#         'postalCode': '1012 JN',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Oudebrugsteeg 15',
#          '1012 JN Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b31',
#          'name': 'Chocolate Shop',
#          'pluralName': 'Chocolate Shops',
#          'shortName': 'Chocolate Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/candystore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5ad253cdb9ac381d6e190d7e-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50903263e4b0bbdbafdcce1f',
#        'name': 'Tales & Spirits',
#        'location': {'address': 'Lijnbaanssteeg 5-7',
#         'crossStreet': '"Btwn De Singel & De Spuistraat',
#         'lat': 52.37621341230454,
#         'lng': 4.891733780575983,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37621341230454,
#           'lng': 4.891733780575983}],
#         'distance': 404,
#         'postalCode': '1012 TE',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Lijnbaanssteeg 5-7 ("Btwn De Singel & De Spuistraat)',
#          '1012 TE Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d11e941735',
#          'name': 'Cocktail Bar',
#          'pluralName': 'Cocktail Bars',
#          'shortName': 'Cocktail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '45366978'}},
#       'referralId': 'e-0-50903263e4b0bbdbafdcce1f-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a2bbd19f964a520db961fe3',
#        'name': 'Gartine',
#        'location': {'address': 'Taksteeg 7',
#         'crossStreet': 'Kalverstraat',
#         'lat': 52.36915717683828,
#         'lng': 4.891615198788351,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.36915717683828,
#           'lng': 4.891615198788351}],
#         'distance': 423,
#         'postalCode': '1012 PB',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Taksteeg 7 (Kalverstraat)',
#          '1012 PB Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d143941735',
#          'name': 'Breakfast Spot',
#          'pluralName': 'Breakfast Spots',
#          'shortName': 'Breakfast',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a2bbd19f964a520db961fe3-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50a1095e067d019650116bbb',
#        'name': 'So Spa at Sofitel Amsterdam',
#        'location': {'address': 'Oudezijds Voorburgwal 197',
#         'lat': 52.37057082073392,
#         'lng': 4.89583135504605,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37057082073392,
#           'lng': 4.89583135504605}],
#         'distance': 286,
#         'cc': 'NL',
#         'city': '1012 EX Amsterdam',
#         'state': '1012 EX Amsterdam',
#         'country': 'Nederland',
#         'formattedAddress': ['Oudezijds Voorburgwal 197',
#          '1012 EX Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1ed941735',
#          'name': 'Spa',
#          'pluralName': 'Spas',
#          'shortName': 'Spa',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50a1095e067d019650116bbb-39'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
# ...
#           'lng': 4.897781077788455}],
#         'distance': 402,
#         'postalCode': '1012 CX',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Kloveniersburgwal 50',
#          '1012 CX Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d137941735',
#          'name': 'Theater',
#          'pluralName': 'Theaters',
#          'shortName': 'Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a27db93f964a52098941fe3-63'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fa80ccde4b0548308c27267',
#        'name': 'Tulip of Amsterdam',
#        'location': {'address': 'Kloveniersburgwal 9- HS',
#         'lat': 52.37203289634296,
#         'lng': 4.899763887565741,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37203289634296,
#           'lng': 4.899763887565741}],
#         'distance': 426,
#         'postalCode': '1011 JT',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Kloveniersburgwal 9- HS',
#          '1011 JT Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1f8931735',
#          'name': 'Bed & Breakfast',
#          'pluralName': 'Bed & Breakfasts',
#          'shortName': 'B & B',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/bedandbreakfast_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fa80ccde4b0548308c27267-64'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53ede5e9498e5c7f3c3f79e7',
#        'name': 'STACH food',
#        'location': {'address': 'Nieuwe Hoogstraat 1A',
#         'crossStreet': 'Kloveniersburgwal 37',
#         'lat': 52.371004437786475,
#         'lng': 4.898924662635418,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.371004437786475,
#           'lng': 4.898924662635418}],
#         'distance': 411,
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Nieuwe Hoogstraat 1A (Kloveniersburgwal 37)',
#          'Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53ede5e9498e5c7f3c3f79e7-65'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a27db3ef964a520ca921fe3',
#        'name': 'Nyonya Malaysia Restaurant',
#        'location': {'address': 'Kloveniersburgwal 38',
#         'lat': 52.37117337970882,
#         'lng': 4.898815283800612,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37117337970882,
#           'lng': 4.898815283800612}],
#         'distance': 395,
#         'postalCode': '1012 CW',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Kloveniersburgwal 38',
#          '1012 CW Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d156941735',
#          'name': 'Malay Restaurant',
#          'pluralName': 'Malay Restaurants',
#          'shortName': 'Malay',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/malaysian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a27db3ef964a520ca921fe3-66'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b753672f964a52046012ee3',
#        'name': 'Vincent Kaas & Vlees',
#        'location': {'address': 'Nieuwmarkt 6',
#         'lat': 52.37292886039606,
#         'lng': 4.900333141590537,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37292886039606,
#           'lng': 4.900333141590537}],
#         'distance': 457,
#         'postalCode': '1012CR',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Nieuwmarkt 6', '1012CR Amsterdam', 'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d146941735',
#          'name': 'Deli / Bodega',
#          'pluralName': 'Delis / Bodegas',
#          'shortName': 'Deli / Bodega',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b753672f964a52046012ee3-67'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b9aaa33f964a52017cb35e3',
#        'name': 'Perdu',
#        'location': {'address': 'Kloveniersburgwal 86',
#         'lat': 52.368887868557344,
#         'lng': 4.89639893049971,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.368887868557344,
#           'lng': 4.89639893049971}],
#         'distance': 471,
#         'postalCode': '1012 CZ',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Kloveniersburgwal 86',
#          '1012 CZ Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d135941735',
#          'name': 'Indie Theater',
#          'pluralName': 'Indie Theaters',
#          'shortName': 'Indie',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b9aaa33f964a52017cb35e3-68'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ff07d30e4b0db68d4939305',
#        'name': 'Candy Freaks',
#        'location': {'lat': 52.37089272315083,
#         'lng': 4.899212841623628,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37089272315083,
#           'lng': 4.899212841623628}],
#         'distance': 434,
#         'cc': 'NL',
#         'country': 'Nederland',
#         'formattedAddress': ['Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1d0941735',
#          'name': 'Dessert Shop',
#          'pluralName': 'Dessert Shops',
#          'shortName': 'Desserts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ff07d30e4b0db68d4939305-69'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a26ff69f964a520857f1fe3',
#        'name': 'Eetcafé Bern',
#        'location': {'address': 'Nieuwmarkt 9',
#         'lat': 52.37257527386424,
#         'lng': 4.900644567966395,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37257527386424,
#           'lng': 4.900644567966395}],
#         'distance': 478,
#         'postalCode': '1011 JR',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Nieuwmarkt 9',
#          '1011 JR Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d158941735',
#          'name': 'Swiss Restaurant',
#          'pluralName': 'Swiss Restaurants',
#          'shortName': 'Swiss',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/swiss_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a26ff69f964a520857f1fe3-70'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51fc08d5e4b0775966536550',
#        'name': 'YoYo! Fresh Tea Bar',
#        'location': {'address': 'Zeedijk 98-100',
#         'lat': 52.37406451609463,
#         'lng': 4.900333527297094,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37406451609463,
#           'lng': 4.900333527297094}],
#         'distance': 479,
#         'postalCode': '1012 BB',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Zeedijk 98-100',
#          '1012 BB Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1dc931735',
#          'name': 'Tea Room',
#          'pluralName': 'Tea Rooms',
#          'shortName': 'Tea Room',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tearoom_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51fc08d5e4b0775966536550-71'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a2706a0f964a5208d8b1fe3',
#        'name': 'The Flying Pig Downtown Hostel',
#        'location': {'address': 'Nieuwendijk 100/VOOR',
#         'lat': 52.376732730950295,
#         'lng': 4.896335231579478,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.376732730950295,
#           'lng': 4.896335231579478}],
#         'distance': 479,
#         'postalCode': '1012 MR',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Nieuwendijk 100/VOOR',
#          '1012 MR Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1ee931735',
#          'name': 'Hostel',
#          'pluralName': 'Hostels',
#          'shortName': 'Hostel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hostel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a2706a0f964a5208d8b1fe3-72'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4badfddaf964a520ba783be3',
#        'name': 'misc eatdrinksleep',
#        'location': {'address': 'Kloveniersburgwal 20',
#         'crossStreet': 'Koestraat',
#         'lat': 52.37172,
#         'lng': 4.899032,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37172,
#           'lng': 4.899032}],
#         'distance': 386,
#         'postalCode': '1012CV',
#         'cc': 'NL',
#         'neighborhood': 'De Wallen',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Kloveniersburgwal 20 (Koestraat)',
#          '1012CV Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '456266411'}},
#       'referralId': 'e-0-4badfddaf964a520ba783be3-73'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ac38268f964a520949b20e3',
#        'name': "Henk's Comics & Manga Store",
#        'location': {'address': 'Geldersekade 96',
#         'lat': 52.37394758508113,
#         'lng': 4.90040832964198,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37394758508113,
#           'lng': 4.90040832964198}],
#         'distance': 480,
#         'postalCode': '1012 BM',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Geldersekade 96',
#          '1012 BM Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b18',
#          'name': 'Comic Shop',
#          'pluralName': 'Comic Shops',
#          'shortName': 'Comic Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/comic_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ac38268f964a520949b20e3-74'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a2703ddf964a520ab851fe3',
#        'name': 'De Compagnon',
#        'location': {'address': 'Guldehandsteeg 17',
#         'lat': 52.37596,
#         'lng': 4.898455,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37596,
#           'lng': 4.898455}],
#         'distance': 485,
#         'postalCode': '1012 RA',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Guldehandsteeg 17',
#          '1012 RA Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a2703ddf964a520ab851fe3-75'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f707285e4b03b575ed77f23',
#        'name': 'Mata Hari',
#        'location': {'address': 'Oudezijds Achterburgwal 22',
#         'lat': 52.37454854921772,
#         'lng': 4.900176632761354,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37454854921772,
#           'lng': 4.900176632761354}],
#         'distance': 489,
#         'postalCode': '1012 DM',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Oudezijds Achterburgwal 22',
#          '1012 DM Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1c0941735',
#          'name': 'Mediterranean Restaurant',
#          'pluralName': 'Mediterranean Restaurants',
#          'shortName': 'Mediterranean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f707285e4b03b575ed77f23-76'}]}]}}

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
#              name    categories        lat       lng
# 0         Hotel V         Hotel  52.371125  4.893665
# 1       The Lobby    Restaurant  52.371159  4.893661
# 2       Scheltema     Bookstore  52.372205  4.893175
# 3             Dam         Plaza  52.372824  4.893702
# 4  Wynand Fockink  Liquor Store  52.372301  4.895253

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 77 venues were returned by Foursquare.

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

manhattan_venues = getNearbyVenues(names=manhattan_data['Neighborhood'],
                                   latitudes=manhattan_data['Latitude'],
                                   longitudes=manhattan_data['Longitude']
                                  )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-82c4f33d7961> in <module>
#      39     return(nearby_venues)
#      40
# ---> 41 manhattan_venues = getNearbyVenues(names=manhattan_data['Neighborhood'],
#      42                                    latitudes=manhattan_data['Latitude'],
#      43                                    longitudes=manhattan_data['Longitude']
#
# NameError: name 'manhattan_data' is not defined
